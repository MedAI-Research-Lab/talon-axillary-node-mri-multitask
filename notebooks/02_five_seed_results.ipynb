# %% [markdown]
# # Five-seed locked-test results
#
# | Model | AUROC | AUPRC | Calibrated Brier | Dice | IoU |
# |---|---:|---:|---:|---:|---:|
# | TALON | 0.905 ± 0.047 | 0.892 ± 0.057 | 0.126 ± 0.032 | 0.530 ± 0.057 | 0.423 ± 0.050 |
# | Mask-guided Multi-task U-Net | 0.838 ± 0.113 | 0.795 ± 0.154 | 0.175 ± 0.052 | 0.424 ± 0.085 | 0.327 ± 0.070 |
#
# ![Per-seed results](../paper_outputs/figures/main/figure_2_five_seed_performance_en.png)

# %%
import pandas as pd

metrics = pd.read_csv("../results/aggregate/all_seed_model_metrics.csv")
metrics.query("calibration == 'calibrated'").head()

# %% [markdown]
# ## Representative segmentation outputs
#
# These are frozen, deidentified manuscript composites. Public release requires the institutional authorization check described in docs/DATA_GOVERNANCE.md.
#
# ![Segmentation examples](../paper_outputs/figures/main/figure_3_test_segmentation_cases_en.png)
