# %% [markdown]
# # Reproduce public paper outputs
#
# Aggregate tables and the five-seed performance figure can be regenerated without private data.

# %%
# %run ../scripts/reproduce_paper_outputs.py --output-dir ../reproduced

# %% [markdown]
# Patient-level segmentation composites cannot be regenerated from this public package because underlying MRI slices and prediction arrays are intentionally excluded.
