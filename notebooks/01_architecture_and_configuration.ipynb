# %% [markdown]
# # TALON architecture and locked configuration
#
# The manuscript name is **TALON**; the internal run identifier retained in result files is HYBRID_TALON.
#
# ![TALON architecture](../paper_outputs/figures/architecture/supplementary_figure_S1_talon_architecture.png)

# %%
import json
from pathlib import Path

config = json.loads(Path("../configs/publication_config.frozen.json").read_text())
config["training"]["teacher_phases"]
