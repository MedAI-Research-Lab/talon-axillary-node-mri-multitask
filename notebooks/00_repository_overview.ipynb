# %% [markdown]
# # TALON IBC–IGM axillary-node DCE-MRI reproducibility repository
#
# This notebook maps the paper workflow to the public code and frozen outputs. No private clinical data are bundled.
#
# ![Workflow](../paper_outputs/figures/main/figure_1_workflow_5seed_en.png)

# %% [markdown]
# ## Contents
#
# - src/: model, losses, training, evaluation, statistics, component analysis, and XAI code
# - results/: sanitized five-seed frozen outputs
# - paper_outputs/: publication figures, tables, and figure source data
# - scripts/: private-data training orchestration and public-output regeneration
